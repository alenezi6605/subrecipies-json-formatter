# %%
import pandas as pd

dtypes = {
    'L': int,
    'Item Code': str,
    'Name': str,
    'Qty': float,
    'Total Qty': float
}

# Read data from Excel file
df = pd.read_excel('recipies_combined.xlsx', dtype=dtypes)

# Initialize the main JSON structure
json_structure = {'recipes': []}
current_recipe = None
current_item = None
current_sub_item = None
current_sub_sub_item = None
current_sub_sub_sub_item = None

# Iterate through DataFrame rows
for _, row in df.iterrows():
    if row['L'] == 1:
        # Create a new main recipe object
        if current_recipe:
            json_structure['recipes'].append(current_recipe)
        current_recipe = {
            'pattern': str(row['Name']).replace(' ', '_'),  # Cast to string explicitly
            'itemCode': str(row['Item Code']),
            'items': []
        }
    elif row['L'] == 2:
        # Create a new item object inside the main recipe
        current_item = {
            'itemCode': str(row['Item Code']),
            'compulsory': False,
            'standardQuantity': row['Total Qty'],
        }
        if current_recipe is not None:
            current_recipe['items'].append(current_item)
    elif row['L'] == 3:
        # Create a new item object inside the current item
        current_sub_item = {
            'itemCode': str(row['Item Code']),
            'compulsory': False,
            'standardQuantity': row['Total Qty'],
        }
        if current_item is not None:
            current_item['items'] = [current_sub_item]
    elif row['L'] == 4:
        # Create a new item object inside the current sub-item
        current_sub_sub_item = {
            'itemCode': str(row['Item Code']),
            'compulsory': False,
            'standardQuantity': row['Total Qty']
        }
        if current_sub_item is not None:
            current_sub_item['items'] = [current_sub_sub_item]
    elif row['L'] == 5:
        # Create a new item object inside the current sub-sub-item
        current_sub_sub_sub_item = {
            'itemCode': str(row['Item Code']),
            'compulsory': False,
            'standardQuantity': row['Total Qty']
        }
        if current_sub_sub_item is not None:
            if 'items' not in current_sub_sub_item:
                current_sub_sub_item['items'] = []
            current_sub_sub_item['items'].append(current_sub_sub_sub_item)

# Append the last recipe
if current_recipe:
    if current_recipe.get('items'):
        json_structure['recipes'].append(current_recipe)

# Print the final JSON structure
import json
print(json.dumps(json_structure, indent=4))
# Out:
# {
#     "recipes": [
#         {
#             "pattern": "CINNAMON_POWDER",
#             "itemCode": "106",
#             "items": []
#         },
#         {
#             "pattern": "PINEAPPLE_",
#             "itemCode": "290",
#             "items": []
#         },
#         {
#             "pattern": "Hawaiin_Sauce_SF",
#             "itemCode": "1008",
#             "items": [
#                 {
#                     "itemCode": "15",
#                     "compulsory": false,
#                     "standardQuantity": 5.71411
#                 },
#                 {
#                     "itemCode": "96",
#                     "compulsory": false,
#                     "standardQuantity": 17.14269
#                 }
#             ]
#         },
#         {
#             "pattern": "Toasted_Shredded_Coconut_SF",
#             "itemCode": "3480",
#             "items": [
#                 {
#                     "itemCode": "283",
#                     "compulsory": false,
#                     "standardQuantity": 3.87628
#                 }
#             ]
#         },
#         {
#             "pattern": "Toasted_Pecan_Nuts_SF",
#             "itemCode": "3569",
#             "items": [
#                 {
#                     "itemCode": "352",
#                     "compulsory": false,
#                     "standardQuantity": 1.59495
#                 }
#             ]
#         },
#         {
#             "pattern": "Toasted_Almond_Flakes_SF",
#             "itemCode": "3574",
#             "items": [
#                 {
#                     "itemCode": "101",
#                     "compulsory": false,
#                     "standardQuantity": 4.00889
#                 }
#             ]
#         },
#         {
#             "pattern": "Banana_Overnight_Oats_SF",
#             "itemCode": "11555",
#             "items": [
#                 {
#                     "itemCode": "15",
#                     "compulsory": false,
#                     "standardQuantity": 12.0004
#                 },
#                 {
#                     "itemCode": "70",
#                     "compulsory": false,
#                     "standardQuantity": 42.99985
#                 },
#                 {
#                     "itemCode": "92",
#                     "compulsory": false,
#                     "standardQuantity": 91.9999
#                 },
#                 {
#                     "itemCode": "271",
#                     "compulsory": false,
#                     "standardQuantity": 15.00015
#                 }
#             ]
#         },
#         {
#             "pattern": "TOMATO_SUNDRIED_(IN_HOUSE)",
#             "itemCode": "400",
#             "items": []
#         },
#         {
#             "pattern": "BROWN_TOAST_BREAD_SF",
#             "itemCode": "820",
#             "items": [
#                 {
#                     "itemCode": "10822",
#                     "compulsory": false,
#                     "standardQuantity": 81.875,
#                     "items": [
#                         {
#                             "itemCode": "12429",
#                             "compulsory": false,
#                             "standardQuantity": 1.727
#                         }
#                     ]
#                 }
#             ]
#         },
#         {
#             "pattern": "Numou_Pesto_Sauce_SF",
#             "itemCode": "7992",
#             "items": [
#                 {
#                     "itemCode": "7",
#                     "compulsory": false,
#                     "standardQuantity": 1.645
#                 },
#                 {
#                     "itemCode": "797",
#                     "compulsory": false,
#                     "standardQuantity": 18.073,
#                     "items": [
#                         {
#                             "itemCode": "12429",
#                             "compulsory": false,
#                             "standardQuantity": 7.327
#                         }
#                     ]
#                 },
#                 {
#                     "itemCode": "12428",
#                     "compulsory": false,
#                     "standardQuantity": 1.175
#                 }
#             ]
#         },
#         {
#             "pattern": "MOZZARELLA_CHEESE_THREE_COW_(RM)",
#             "itemCode": "11904",
#             "items": []
#         },
#         {
#             "pattern": "Olive_Slice_Black_-_Virginia_garden",
#             "itemCode": "12439",
#             "items": []
#         },
#         {
#             "pattern": "CINNAMON_POWDER",
#             "itemCode": "106",
#             "items": []
#         },
#         {
#             "pattern": "PUMPKIN_SEED",
#             "itemCode": "181",
#             "items": []
#         },
#         {
#             "pattern": "Overnight_Oats_SF",
#             "itemCode": "3559",
#             "items": [
#                 {
#                     "itemCode": "15",
#                     "compulsory": false,
#                     "standardQuantity": 11.842
#                 },
#                 {
#                     "itemCode": "70",
#                     "compulsory": false,
#                     "standardQuantity": 47.369
#                 },
#                 {
#                     "itemCode": "92",
#                     "compulsory": false,
#                     "standardQuantity": 94.737
#                 }
#             ]
#         },
#         {
#             "pattern": "Toasted_Pecan_Nuts_SF",
#             "itemCode": "3569",
#             "items": [
#                 {
#                     "itemCode": "352",
#                     "compulsory": false,
#                     "standardQuantity": 3.03
#                 }
#             ]
#         },
#         {
#             "pattern": "Pumpkin_Puree_SF",
#             "itemCode": "3618",
#             "items": [
#                 {
#                     "itemCode": "278",
#                     "compulsory": false,
#                     "standardQuantity": 39.818
#                 },
#                 {
#                     "itemCode": "7991",
#                     "compulsory": false,
#                     "standardQuantity": 60.606
#                 }
#             ]
#         },
#         {
#             "pattern": "CHEESE_CHEDDAR_LOW_FAT",
#             "itemCode": "83",
#             "items": []
#         },
#         {
#             "pattern": "Caramelized_Onions_SF",
#             "itemCode": "796",
#             "items": [
#                 {
#                     "itemCode": "8",
#                     "compulsory": false,
#                     "standardQuantity": 5.217
#                 },
#                 {
#                     "itemCode": "15",
#                     "compulsory": false,
#                     "standardQuantity": 2.609
#                 },
#                 {
#                     "itemCode": "18",
#                     "compulsory": false,
#                     "standardQuantity": 1.304
#                 },
#                 {
#                     "itemCode": "103",
#                     "compulsory": false,
#                     "standardQuantity": 0.013
#                 },
#                 {
#                     "itemCode": "106",
#                     "compulsory": false,
#                     "standardQuantity": 0.039
#                 },
#                 {
#                     "itemCode": "117",
#                     "compulsory": false,
#                     "standardQuantity": 0.261
#                 },
#                 {
#                     "itemCode": "432",
#                     "compulsory": false,
#                     "standardQuantity": 39.13
#                 }
#             ]
#         },
#         {
#             "pattern": "SAJ_BREAD_SF",
#             "itemCode": "822",
#             "items": [
#                 {
#                     "itemCode": "257",
#                     "compulsory": false,
#                     "standardQuantity": 10.0
#                 },
#                 {
#                     "itemCode": "8364",
#                     "compulsory": false,
#                     "standardQuantity": 60.0,
#                     "items": [
#                         {
#                             "itemCode": "7991",
#                             "compulsory": false,
#                             "standardQuantity": 18.966
#                         }
#                     ]
#                 }
#             ]
#         },
#         {
#             "pattern": "Scrambled_Cheesy_Kale_Eggs_SF",
#             "itemCode": "3696",
#             "items": [
#                 {
#                     "itemCode": "18",
#                     "compulsory": false,
#                     "standardQuantity": 1.823
#                 },
#                 {
#                     "itemCode": "103",
#                     "compulsory": false,
#                     "standardQuantity": 0.045
#                 },
#                 {
#                     "itemCode": "117",
#                     "compulsory": false,
#                     "standardQuantity": 0.452
#                 },
#                 {
#                     "itemCode": "432",
#                     "compulsory": false,
#                     "standardQuantity": 4.516
#                 },
#                 {
#                     "itemCode": "449",
#                     "compulsory": false,
#                     "standardQuantity": 6.752
#                 },
#                 {
#                     "itemCode": "454",
#                     "compulsory": false,
#                     "standardQuantity": 6.865
#                 },
#                 {
#                     "itemCode": "3739",
#                     "compulsory": false,
#                     "standardQuantity": 9.032,
#                     "items": [
#                         {
#                             "itemCode": "1831",
#                             "compulsory": false,
#                             "standardQuantity": 0.036
#                         }
#                     ]
#                 },
#                 {
#                     "itemCode": "7724",
#                     "compulsory": false,
#                     "standardQuantity": 54.194,
#                     "items": [
#                         {
#                             "itemCode": "1059",
#                             "compulsory": false,
#                             "standardQuantity": 5.432
#                         }
#                     ]
#                 }
#             ]
#         },
#         {
#             "pattern": "Mayo_With_Sriracha_SF",
#             "itemCode": "7747",
#             "items": [
#                 {
#                     "itemCode": "21",
#                     "compulsory": false,
#                     "standardQuantity": 2.291
#                 },
#                 {
#                     "itemCode": "117",
#                     "compulsory": false,
#                     "standardQuantity": 0.114
#                 },
#                 {
#                     "itemCode": "8027",
#                     "compulsory": false,
#                     "standardQuantity": 17.143
#                 },
#                 {
#                     "itemCode": "8077",
#                     "compulsory": false,
#                     "standardQuantity": 1.143
#                 }
#             ]
#         },
#         {
#             "pattern": "CHEESE_MOZZARELLA_LOW_FAT",
#             "itemCode": "89",
#             "items": []
#         },
#         {
#             "pattern": "Caramelized_Onions_SF",
#             "itemCode": "796",
#             "items": [
#                 {
#                     "itemCode": "8",
#                     "compulsory": false,
#                     "standardQuantity": 3.47824
#                 },
#                 {
#                     "itemCode": "15",
#                     "compulsory": false,
#                     "standardQuantity": 1.73916
#                 },
#                 {
#                     "itemCode": "18",
#                     "compulsory": false,
#                     "standardQuantity": 0.86954
#                 },
#                 {
#                     "itemCode": "103",
#                     "compulsory": false,
#                     "standardQuantity": 0.00869
#                 },
#                 {
#                     "itemCode": "106",
#                     "compulsory": false,
#                     "standardQuantity": 0.02606
#                 },
#                 {
#                     "itemCode": "117",
#                     "compulsory": false,
#                     "standardQuantity": 0.17393
#                 },
#                 {
#                     "itemCode": "432",
#                     "compulsory": false,
#                     "standardQuantity": 26.08696
#                 }
#             ]
#         },
#         {
#             "pattern": "Sourdough_Slice_SF",
#             "itemCode": "7948",
#             "items": [
#                 {
#                     "itemCode": "7947",
#                     "compulsory": false,
#                     "standardQuantity": 50.0,
#                     "items": [
#                         {
#                             "itemCode": "7946",
#                             "compulsory": false,
#                             "standardQuantity": 71.42857,
#                             "items": [
#                                 {
#                                     "itemCode": "7991",
#                                     "compulsory": false,
#                                     "standardQuantity": 31.54574
#                                 }
#                             ]
#                         }
#                     ]
#                 }
#             ]
#         },
#         {
#             "pattern": "Mushroom_Swiss_Sandwich_SF",
#             "itemCode": "10223",
#             "items": [
#                 {
#                     "itemCode": "8",
#                     "compulsory": false,
#                     "standardQuantity": 19.99968
#                 },
#                 {
#                     "itemCode": "18",
#                     "compulsory": false,
#                     "standardQuantity": 4.99985
#                 },
#                 {
#                     "itemCode": "117",
#                     "compulsory": false,
#                     "standardQuantity": 1.00007
#                 },
#                 {
#                     "itemCode": "445",
#                     "compulsory": false,
#                     "standardQuantity": 99.9999
#                 },
#                 {
#                     "itemCode": "1829",
#                     "compulsory": false,
#                     "standardQuantity": 0.19982
#                 },
#                 {
#                     "itemCode": "1830",
#                     "compulsory": false,
#                     "standardQuantity": 0.19982
#                 },
#                 {
#                     "itemCode": "1831",
#                     "compulsory": false,
#                     "standardQuantity": 0.29973
#                 }
#             ]
#         },
#         {
#             "pattern": "CHIA_SEEDS",
#             "itemCode": "411",
#             "items": []
#         },
#         {
#             "pattern": "Blueberry_Jam_SF_",
#             "itemCode": "983",
#             "items": [
#                 {
#                     "itemCode": "15",
#                     "compulsory": false,
#                     "standardQuantity": 6.684
#                 },
#                 {
#                     "itemCode": "296",
#                     "compulsory": false,
#                     "standardQuantity": 0.134,
#                     "items": [
#                         {
#                             "itemCode": "444",
#                             "compulsory": false,
#                             "standardQuantity": 0.134
#                         }
#                     ]
#                 },
#                 {
#                     "itemCode": "304",
#                     "compulsory": false,
#                     "standardQuantity": 13.369
#                 }
#             ]
#         },
#         {
#             "pattern": "Whipping_Cream_SF",
#             "itemCode": "8530",
#             "items": [
#                 {
#                     "itemCode": "81",
#                     "compulsory": false,
#                     "standardQuantity": 7.018
#                 }
#             ]
#         },
#         {
#             "pattern": "Blueberry_Chia_Pancake_Base_SF",
#             "itemCode": "10238",
#             "items": [
#                 {
#                     "itemCode": "3021",
#                     "compulsory": false,
#                     "standardQuantity": 2.0
#                 },
#                 {
#                     "itemCode": "3598",
#                     "compulsory": false,
#                     "standardQuantity": 110.0,
#                     "items": [
#                         {
#                             "itemCode": "7991",
#                             "compulsory": false,
#                             "standardQuantity": 11.957
#                         }
#                     ]
#                 }
#             ]
#         },
#         {
#             "pattern": "MAPLE_SYRUP",
#             "itemCode": "16",
#             "items": []
#         },
#         {
#             "pattern": "CINNAMON_POWDER",
#             "itemCode": "106",
#             "items": []
#         },
#         {
#             "pattern": "STRAWBERRY",
#             "itemCode": "280",
#             "items": []
#         },
#         {
#             "pattern": "Cinnamon_Waffles_Base_SF",
#             "itemCode": "10163",
#             "items": [
#                 {
#                     "itemCode": "3021",
#                     "compulsory": false,
#                     "standardQuantity": 1.0
#                 },
#                 {
#                     "itemCode": "3601",
#                     "compulsory": false,
#                     "standardQuantity": 76.0,
#                     "items": [
#                         {
#                             "itemCode": "3056",
#                             "compulsory": false,
#                             "standardQuantity": 1.983
#                         }
#                     ]
#                 }
#             ]
#         },
#         {
#             "pattern": "NATURAL_HONEY",
#             "itemCode": "15",
#             "items": []
#         },
#         {
#             "pattern": "APPLE_RED_",
#             "itemCode": "269",
#             "items": []
#         },
#         {
#             "pattern": "STRAWBERRY",
#             "itemCode": "280",
#             "items": []
#         },
#         {
#             "pattern": "CHIA_SEEDS",
#             "itemCode": "411",
#             "items": []
#         },
#         {
#             "pattern": "Overnight_Oats_SF",
#             "itemCode": "3559",
#             "items": [
#                 {
#                     "itemCode": "15",
#                     "compulsory": false,
#                     "standardQuantity": 7.895
#                 },
#                 {
#                     "itemCode": "70",
#                     "compulsory": false,
#                     "standardQuantity": 31.579
#                 },
#                 {
#                     "itemCode": "92",
#                     "compulsory": false,
#                     "standardQuantity": 63.158
#                 }
#             ]
#         },
#         {
#             "pattern": "Toasted_Pecan_Nuts_SF",
#             "itemCode": "3569",
#             "items": [
#                 {
#                     "itemCode": "352",
#                     "compulsory": false,
#                     "standardQuantity": 2.475
#                 }
#             ]
#         },
#         {
#             "pattern": "nan",
#             "itemCode": "nan",
#             "items": []
#         },
#         {
#             "pattern": "Waffle_Maple_Syrup_Sauce_SF",
#             "itemCode": "3420",
#             "items": [
#                 {
#                     "itemCode": "16",
#                     "compulsory": false,
#                     "standardQuantity": 15.0
#                 },
#                 {
#                     "itemCode": "1077",
#                     "compulsory": false,
#                     "standardQuantity": 1.5
#                 }
#             ]
#         },
#         {
#             "pattern": "Toasted_Almond_Flakes_SF",
#             "itemCode": "3574",
#             "items": [
#                 {
#                     "itemCode": "101",
#                     "compulsory": false,
#                     "standardQuantity": 2.339
#                 }
#             ]
#         },
#         {
#             "pattern": "Blueberry_Waffle_Base_SF",
#             "itemCode": "10249",
#             "items": [
#                 {
#                     "itemCode": "3021",
#                     "compulsory": false,
#                     "standardQuantity": 1.0
#                 },
#                 {
#                     "itemCode": "3418",
#                     "compulsory": false,
#                     "standardQuantity": 67.0,
#                     "items": [
#                         {
#                             "itemCode": "3056",
#                             "compulsory": false,
#                             "standardQuantity": 1.675
#                         }
#                     ]
#                 }
#             ]
#         },
#         {
#             "pattern": "STRAWBERRY",
#             "itemCode": "280",
#             "items": []
#         },
#         {
#             "pattern": "Chocolate_Sauce_SF",
#             "itemCode": "829",
#             "items": [
#                 {
#                     "itemCode": "2",
#                     "compulsory": false,
#                     "standardQuantity": 0.5
#                 },
#                 {
#                     "itemCode": "15",
#                     "compulsory": false,
#                     "standardQuantity": 7.5
#                 },
#                 {
#                     "itemCode": "84",
#                     "compulsory": false,
#                     "standardQuantity": 5.0
#                 },
#                 {
#                     "itemCode": "174",
#                     "compulsory": false,
#                     "standardQuantity": 2.5
#                 },
#                 {
#                     "itemCode": "184",
#                     "compulsory": false,
#                     "standardQuantity": 0.25
#                 },
#                 {
#                     "itemCode": "7991",
#                     "compulsory": false,
#                     "standardQuantity": 2.5
#                 }
#             ]
#         },
#         {
#             "pattern": "Chocolate_Chip_Waffle_Base_SF",
#             "itemCode": "10164",
#             "items": [
#                 {
#                     "itemCode": "3021",
#                     "compulsory": false,
#                     "standardQuantity": 1.0
#                 },
#                 {
#                     "itemCode": "3602",
#                     "compulsory": false,
#                     "standardQuantity": 77.5,
#                     "items": [
#                         {
#                             "itemCode": "3056",
#                             "compulsory": false,
#                             "standardQuantity": 1.938
#                         }
#                     ]
#                 }
#             ]
#         },
#         {
#             "pattern": "BROWN_TOAST_BREAD_SF",
#             "itemCode": "820",
#             "items": [
#                 {
#                     "itemCode": "10822",
#                     "compulsory": false,
#                     "standardQuantity": 122.813,
#                     "items": [
#                         {
#                             "itemCode": "10161",
#                             "compulsory": false,
#                             "standardQuantity": 142.504,
#                             "items": [
#                                 {
#                                     "itemCode": "7991",
#                                     "compulsory": false,
#                                     "standardQuantity": 29.339
#                                 }
#                             ]
#                         }
#                     ]
#                 }
#             ]
#         },
#         {
#             "pattern": "Cheese__Omelet_SF",
#             "itemCode": "10201",
#             "items": [
#                 {
#                     "itemCode": "83",
#                     "compulsory": false,
#                     "standardQuantity": 15.0
#                 },
#                 {
#                     "itemCode": "89",
#                     "compulsory": false,
#                     "standardQuantity": 15.0
#                 },
#                 {
#                     "itemCode": "3695",
#                     "compulsory": false,
#                     "standardQuantity": 90.0,
#                     "items": [
#                         {
#                             "itemCode": "376",
#                             "compulsory": false,
#                             "standardQuantity": 108.0
#                         }
#                     ]
#                 }
#             ]
#         },
#         {
#             "pattern": "CHEESE_CHEDDAR_LOW_FAT",
#             "itemCode": "83",
#             "items": []
#         },
#         {
#             "pattern": "SAJ_BREAD_SF",
#             "itemCode": "822",
#             "items": [
#                 {
#                     "itemCode": "257",
#                     "compulsory": false,
#                     "standardQuantity": 10.0
#                 },
#                 {
#                     "itemCode": "8364",
#                     "compulsory": false,
#                     "standardQuantity": 60.0,
#                     "items": [
#                         {
#                             "itemCode": "7991",
#                             "compulsory": false,
#                             "standardQuantity": 18.966
#                         }
#                     ]
#                 }
#             ]
#         },
#         {
#             "pattern": "Plain_Scrambled_Eggs_SF",
#             "itemCode": "3692",
#             "items": [
#                 {
#                     "itemCode": "18",
#                     "compulsory": false,
#                     "standardQuantity": 1.167
#                 },
#                 {
#                     "itemCode": "117",
#                     "compulsory": false,
#                     "standardQuantity": 0.233
#                 },
#                 {
#                     "itemCode": "432",
#                     "compulsory": false,
#                     "standardQuantity": 9.333
#                 },
#                 {
#                     "itemCode": "443",
#                     "compulsory": false,
#                     "standardQuantity": 7.0
#                 },
#                 {
#                     "itemCode": "7724",
#                     "compulsory": false,
#                     "standardQuantity": 60.667,
#                     "items": [
#                         {
#                             "itemCode": "1059",
#                             "compulsory": false,
#                             "standardQuantity": 6.08
#                         }
#                     ]
#                 }
#             ]
#         },
#         {
#             "pattern": "VINEGAR_APPLE_CIDER",
#             "itemCode": "7",
#             "items": []
#         },
#         {
#             "pattern": "OIL_OLIVE",
#             "itemCode": "18",
#             "items": []
#         },
#         {
#             "pattern": "MAYONAISE_LIGHT_HEINZ_",
#             "itemCode": "77",
#             "items": []
#         },
#         {
#             "pattern": "PEPPER_BLACK",
#             "itemCode": "103",
#             "items": []
#         },
#         {
#             "pattern": "SEA_SALT",
#             "itemCode": "117",
#             "items": []
#         },
#         {
#             "pattern": "ONION_WHITE",
#             "itemCode": "432",
#             "items": []
#         },
#         {
#             "pattern": "CARROT",
#             "itemCode": "433",
#             "items": []
#         },
#         {
#             "pattern": "DILL_LEAVES",
#             "itemCode": "437",
#             "items": []
#         },
#         {
#             "pattern": "TOMATO_FRESH",
#             "itemCode": "443",
#             "items": []
#         },
#         {
#             "pattern": "KALE",
#             "itemCode": "449",
#             "items": []
#         },
#         {
#             "pattern": "LETTUCE_ICEBERG",
#             "itemCode": "487",
#             "items": []
#         },
#         {
#             "pattern": "SAJ_BREAD_SF",
#             "itemCode": "822",
#             "items": [
#                 {
#                     "itemCode": "257",
#                     "compulsory": false,
#                     "standardQuantity": 10.0
#                 },
#                 {
#                     "itemCode": "8364",
#                     "compulsory": false,
#                     "standardQuantity": 60.0,
#                     "items": [
#                         {
#                             "itemCode": "7991",
#                             "compulsory": false,
#                             "standardQuantity": 18.966
#                         }
#                     ]
#                 }
#             ]
#         },
#         {
#             "pattern": "Hummos_SF",
#             "itemCode": "2160",
#             "items": [
#                 {
#                     "itemCode": "18",
#                     "compulsory": false,
#                     "standardQuantity": 0.92
#                 },
#                 {
#                     "itemCode": "117",
#                     "compulsory": false,
#                     "standardQuantity": 0.046
#                 },
#                 {
#                     "itemCode": "296",
#                     "compulsory": false,
#                     "standardQuantity": 0.345,
#                     "items": [
#                         {
#                             "itemCode": "444",
#                             "compulsory": false,
#                             "standardQuantity": 0.345
#                         }
#                     ]
#                 },
#                 {
#                     "itemCode": "391",
#                     "compulsory": false,
#                     "standardQuantity": 2.069
#                 },
#                 {
#                     "itemCode": "447",
#                     "compulsory": false,
#                     "standardQuantity": 0.138
#                 },
#                 {
#                     "itemCode": "3666",
#                     "compulsory": false,
#                     "standardQuantity": 13.793,
#                     "items": [
#                         {
#                             "itemCode": "7991",
#                             "compulsory": false,
#                             "standardQuantity": 22.989
#                         }
#                     ]
#                 },
#                 {
#                     "itemCode": "7991",
#                     "compulsory": false,
#                     "standardQuantity": 4.138
#                 }
#             ]
#         },
#         {
#             "pattern": "STRAWBERRY",
#             "itemCode": "280",
#             "items": []
#         },
#         {
#             "pattern": "Lemon_Vanilla_Sauce_SF",
#             "itemCode": "803",
#             "items": [
#                 {
#                     "itemCode": "296",
#                     "compulsory": false,
#                     "standardQuantity": 0.484,
#                     "items": [
#                         {
#                             "itemCode": "444",
#                             "compulsory": false,
#                             "standardQuantity": 0.484
#                         }
#                     ]
#                 },
#                 {
#                     "itemCode": "895",
#                     "compulsory": false,
#                     "standardQuantity": 0.121,
#                     "items": [
#                         {
#                             "itemCode": "444",
#                             "compulsory": false,
#                             "standardQuantity": 0.121
#                         }
#                     ]
#                 },
#                 {
#                     "itemCode": "3577",
#                     "compulsory": false,
#                     "standardQuantity": 14.516,
#                     "items": [
#                         {
#                             "itemCode": "262",
#                             "compulsory": false,
#                             "standardQuantity": 0.294
#                         }
#                     ]
#                 }
#             ]
#         },
#         {
#             "pattern": "Lemon_Zesty_Pancake_Base_SF",
#             "itemCode": "9471",
#             "items": [
#                 {
#                     "itemCode": "3021",
#                     "compulsory": false,
#                     "standardQuantity": 3.0
#                 },
#                 {
#                     "itemCode": "3596",
#                     "compulsory": false,
#                     "standardQuantity": 112.0
#                 }
#             ]
#         },
#         {
#             "pattern": "BLUEBERRY",
#             "itemCode": "273",
#             "items": []
#         },
#         {
#             "pattern": "STRAWBERRY",
#             "itemCode": "280",
#             "items": []
#         },
#         {
#             "pattern": "Vanilla_Sauce_SF",
#             "itemCode": "3577",
#             "items": [
#                 {
#                     "itemCode": "2",
#                     "compulsory": false,
#                     "standardQuantity": 0.061
#                 },
#                 {
#                     "itemCode": "15",
#                     "compulsory": false,
#                     "standardQuantity": 3.041
#                 },
#                 {
#                     "itemCode": "84",
#                     "compulsory": false,
#                     "standardQuantity": 3.041
#                 },
#                 {
#                     "itemCode": "92",
#                     "compulsory": false,
#                     "standardQuantity": 9.122
#                 },
#                 {
#                     "itemCode": "262",
#                     "compulsory": false,
#                     "standardQuantity": 0.304
#                 }
#             ]
#         },
#         {
#             "pattern": "Fluffy_Yoghurt__Pancake_Base_SF",
#             "itemCode": "10239",
#             "items": [
#                 {
#                     "itemCode": "3021",
#                     "compulsory": false,
#                     "standardQuantity": 2.0
#                 },
#                 {
#                     "itemCode": "3597",
#                     "compulsory": false,
#                     "standardQuantity": 108.0,
#                     "items": [
#                         {
#                             "itemCode": "7991",
#                             "compulsory": false,
#                             "standardQuantity": 7.364
#                         }
#                     ]
#                 }
#             ]
#         },
#         {
#             "pattern": "CHEESE_MOZZARELLA_LOW_FAT",
#             "itemCode": "89",
#             "items": []
#         },
#         {
#             "pattern": "Penne_Pasta_SF",
#             "itemCode": "3338",
#             "items": [
#                 {
#                     "itemCode": "18",
#                     "compulsory": false,
#                     "standardQuantity": 2.0
#                 },
#                 {
#                     "itemCode": "117",
#                     "compulsory": false,
#                     "standardQuantity": 3.0
#                 },
#                 {
#                     "itemCode": "360",
#                     "compulsory": false,
#                     "standardQuantity": 40.09
#                 },
#                 {
#                     "itemCode": "7991",
#                     "compulsory": false,
#                     "standardQuantity": 200.0
#                 }
#             ]
#         },
#         {
#             "pattern": "Pink_Penne_Pasta_Sauce_SF",
#             "itemCode": "4011",
#             "items": [
#                 {
#                     "itemCode": "18",
#                     "compulsory": false,
#                     "standardQuantity": 2.087
#                 },
#                 {
#                     "itemCode": "84",
#                     "compulsory": false,
#                     "standardQuantity": 15.652
#                 },
#                 {
#                     "itemCode": "89",
#                     "compulsory": false,
#                     "standardQuantity": 4.174
#                 },
#                 {
#                     "itemCode": "90",
#                     "compulsory": false,
#                     "standardQuantity": 2.087
#                 },
#                 {
#                     "itemCode": "103",
#                     "compulsory": false,
#                     "standardQuantity": 0.104
#                 },
#                 {
#                     "itemCode": "117",
#                     "compulsory": false,
#                     "standardQuantity": 0.522
#                 },
#                 {
#                     "itemCode": "433",
#                     "compulsory": false,
#                     "standardQuantity": 16.696
#                 },
#                 {
#                     "itemCode": "447",
#                     "compulsory": false,
#                     "standardQuantity": 2.087
#                 },
#                 {
#                     "itemCode": "1831",
#                     "compulsory": false,
#                     "standardQuantity": 0.052
#                 },
#                 {
#                     "itemCode": "3718",
#                     "compulsory": false,
#                     "standardQuantity": 104.348,
#                     "items": [
#                         {
#                             "itemCode": "7704",
#                             "compulsory": false,
#                             "standardQuantity": 39.51,
#                             "items": [
#                                 {
#                                     "itemCode": "7991",
#                                     "compulsory": false,
#                                     "standardQuantity": 60.784
#                                 }
#                             ]
#                         }
#                     ]
#                 },
#                 {
#                     "itemCode": "4326",
#                     "compulsory": false,
#                     "standardQuantity": 6.261,
#                     "items": [
#                         {
#                             "itemCode": "1831",
#                             "compulsory": false,
#                             "standardQuantity": 0.063
#                         }
#                     ]
#                 },
#                 {
#                     "itemCode": "7704",
#                     "compulsory": false,
#                     "standardQuantity": 31.304,
#                     "items": [
#                         {
#                             "itemCode": "7991",
#                             "compulsory": false,
#                             "standardQuantity": 48.161
#                         }
#                     ]
#                 }
#             ]
#         },
#         {
#             "pattern": "CHEESE_PARMESAN_LOW_FAT",
#             "itemCode": "90",
#             "items": []
#         },
#         {
#             "pattern": "Mushroom_Barley_Risotto_SF_",
#             "itemCode": "4301",
#             "items": [
#                 {
#                     "itemCode": "15",
#                     "compulsory": false,
#                     "standardQuantity": 8.0
#                 },
#                 {
#                     "itemCode": "84",
#                     "compulsory": false,
#                     "standardQuantity": 16.0
#                 },
#                 {
#                     "itemCode": "89",
#                     "compulsory": false,
#                     "standardQuantity": 3.2
#                 },
#                 {
#                     "itemCode": "90",
#                     "compulsory": false,
#                     "standardQuantity": 4.8
#                 },
#                 {
#                     "itemCode": "103",
#                     "compulsory": false,
#                     "standardQuantity": 0.16
#                 },
#                 {
#                     "itemCode": "117",
#                     "compulsory": false,
#                     "standardQuantity": 1.6
#                 },
#                 {
#                     "itemCode": "119",
#                     "compulsory": false,
#                     "standardQuantity": 0.16
#                 },
#                 {
#                     "itemCode": "138",
#                     "compulsory": false,
#                     "standardQuantity": 0.024
#                 },
#                 {
#                     "itemCode": "306",
#                     "compulsory": false,
#                     "standardQuantity": 32.0
#                 },
#                 {
#                     "itemCode": "447",
#                     "compulsory": false,
#                     "standardQuantity": 1.6
#                 },
#                 {
#                     "itemCode": "459",
#                     "compulsory": false,
#                     "standardQuantity": 0.8
#                 },
#                 {
#                     "itemCode": "465",
#                     "compulsory": false,
#                     "standardQuantity": 0.8
#                 },
#                 {
#                     "itemCode": "1831",
#                     "compulsory": false,
#                     "standardQuantity": 0.24
#                 },
#                 {
#                     "itemCode": "3710",
#                     "compulsory": false,
#                     "standardQuantity": 24.0,
#                     "items": [
#                         {
#                             "itemCode": "445",
#                             "compulsory": false,
#                             "standardQuantity": 43.636
#                         }
#                     ]
#                 },
#                 {
#                     "itemCode": "7704",
#                     "compulsory": false,
#                     "standardQuantity": 120.0,
#                     "items": [
#                         {
#                             "itemCode": "7991",
#                             "compulsory": false,
#                             "standardQuantity": 184.615
#                         }
#                     ]
#                 }
#             ]
#         },
#         {
#             "pattern": "LIME_FRESH",
#             "itemCode": "1087",
#             "items": []
#         },
#         {
#             "pattern": "Numou_Mashed_Potato_SF",
#             "itemCode": "2997",
#             "items": [
#                 {
#                     "itemCode": "83",
#                     "compulsory": false,
#                     "standardQuantity": 1.636
#                 },
#                 {
#                     "itemCode": "84",
#                     "compulsory": false,
#                     "standardQuantity": 8.182
#                 },
#                 {
#                     "itemCode": "117",
#                     "compulsory": false,
#                     "standardQuantity": 0.655
#                 },
#                 {
#                     "itemCode": "120",
#                     "compulsory": false,
#                     "standardQuantity": 0.082
#                 },
#                 {
#                     "itemCode": "1059",
#                     "compulsory": false,
#                     "standardQuantity": 24.546
#                 },
#                 {
#                     "itemCode": "1077",
#                     "compulsory": false,
#                     "standardQuantity": 1.636
#                 },
#                 {
#                     "itemCode": "4237",
#                     "compulsory": false,
#                     "standardQuantity": 81.818,
#                     "items": [
#                         {
#                             "itemCode": "7991",
#                             "compulsory": false,
#                             "standardQuantity": 288.77
#                         }
#                     ]
#                 }
#             ]
#         },
#         {
#             "pattern": "Glazed_Balsamic_Salmon_Sauce_SF",
#             "itemCode": "4245",
#             "items": [
#                 {
#                     "itemCode": "8",
#                     "compulsory": false,
#                     "standardQuantity": 11.795
#                 },
#                 {
#                     "itemCode": "15",
#                     "compulsory": false,
#                     "standardQuantity": 10.318
#                 },
#                 {
#                     "itemCode": "17",
#                     "compulsory": false,
#                     "standardQuantity": 1.106
#                 },
#                 {
#                     "itemCode": "18",
#                     "compulsory": false,
#                     "standardQuantity": 1.106
#                 },
#                 {
#                     "itemCode": "103",
#                     "compulsory": false,
#                     "standardQuantity": 0.037
#                 },
#                 {
#                     "itemCode": "117",
#                     "compulsory": false,
#                     "standardQuantity": 0.737
#                 },
#                 {
#                     "itemCode": "119",
#                     "compulsory": false,
#                     "standardQuantity": 0.015
#                 },
#                 {
#                     "itemCode": "262",
#                     "compulsory": false,
#                     "standardQuantity": 1.474
#                 },
#                 {
#                     "itemCode": "296",
#                     "compulsory": false,
#                     "standardQuantity": 2.211,
#                     "items": [
#                         {
#                             "itemCode": "444",
#                             "compulsory": false,
#                             "standardQuantity": 2.211
#                         }
#                     ]
#                 },
#                 {
#                     "itemCode": "384",
#                     "compulsory": false,
#                     "standardQuantity": 5.18
#                 },
#                 {
#                     "itemCode": "447",
#                     "compulsory": false,
#                     "standardQuantity": 1.474
#                 },
#                 {
#                     "itemCode": "476",
#                     "compulsory": false,
#                     "standardQuantity": 1.474
#                 },
#                 {
#                     "itemCode": "1077",
#                     "compulsory": false,
#                     "standardQuantity": 0.737
#                 },
#                 {
#                     "itemCode": "7991",
#                     "compulsory": false,
#                     "standardQuantity": 81.053
#                 }
#             ]
#         },
#         {
#             "pattern": "Glazed_Balsamic_Salmon_SF",
#             "itemCode": "4246",
#             "items": [
#                 {
#                     "itemCode": "3641",
#                     "compulsory": false,
#                     "standardQuantity": 65.0,
#                     "items": [
#                         {
#                             "itemCode": "3621",
#                             "compulsory": false,
#                             "standardQuantity": 25.0,
#                             "items": [
#                                 {
#                                     "itemCode": "1815",
#                                     "compulsory": false,
#                                     "standardQuantity": 0.357
#                                 }
#                             ]
#                         }
#                     ]
#                 },
#                 {
#                     "itemCode": "4245",
#                     "compulsory": false,
#                     "standardQuantity": 20.0,
#                     "items": [
#                         {
#                             "itemCode": "7991",
#                             "compulsory": false,
#                             "standardQuantity": 23.158
#                         }
#                     ]
#                 }
#             ]
#         },
#         {
#             "pattern": "LEMON_FRESH",
#             "itemCode": "444",
#             "items": []
#         },
#         {
#             "pattern": "Numou_brown_rice_SF",
#             "itemCode": "833",
#             "items": [
#                 {
#                     "itemCode": "18",
#                     "compulsory": false,
#                     "standardQuantity": 0.453
#                 },
#                 {
#                     "itemCode": "117",
#                     "compulsory": false,
#                     "standardQuantity": 2.7
#                 },
#                 {
#                     "itemCode": "126",
#                     "compulsory": false,
#                     "standardQuantity": 0.18
#                 },
#                 {
#                     "itemCode": "155",
#                     "compulsory": false,
#                     "standardQuantity": 0.45
#                 },
#                 {
#                     "itemCode": "161",
#                     "compulsory": false,
#                     "standardQuantity": 0.45
#                 },
#                 {
#                     "itemCode": "310",
#                     "compulsory": false,
#                     "standardQuantity": 36.081
#                 },
#                 {
#                     "itemCode": "7991",
#                     "compulsory": false,
# ...
#                     "standardQuantity": 2.308
#                 },
#                 {
#                     "itemCode": "103",
#                     "compulsory": false,
#                     "standardQuantity": 0.069
#                 },
#                 {
#                     "itemCode": "112",
#                     "compulsory": false,
#                     "standardQuantity": 0.092
#                 },
#                 {
#                     "itemCode": "117",
#                     "compulsory": false,
#                     "standardQuantity": 1.154
#                 },
#                 {
#                     "itemCode": "296",
#                     "compulsory": false,
#                     "standardQuantity": 1.846,
#                     "items": [
#                         {
#                             "itemCode": "444",
#                             "compulsory": false,
#                             "standardQuantity": 1.846
#                         }
#                     ]
#                 },
#                 {
#                     "itemCode": "447",
#                     "compulsory": false,
#                     "standardQuantity": 2.077
#                 },
#                 {
#                     "itemCode": "453",
#                     "compulsory": false,
#                     "standardQuantity": 29.077
#                 },
#                 {
#                     "itemCode": "457",
#                     "compulsory": false,
#                     "standardQuantity": 27.692
#                 },
#                 {
#                     "itemCode": "1830",
#                     "compulsory": false,
#                     "standardQuantity": 0.069
#                 },
#                 {
#                     "itemCode": "7991",
#                     "compulsory": false,
#                     "standardQuantity": 101.538
#                 }
#             ]
#         },
#         {
#             "pattern": "SWEET_CORN_KERNEL",
#             "itemCode": "14",
#             "items": []
#         },
#         {
#             "pattern": "CHEESE_FETA_LOW_FAT_",
#             "itemCode": "85",
#             "items": []
#         },
#         {
#             "pattern": "WALNUT",
#             "itemCode": "355",
#             "items": []
#         },
#         {
#             "pattern": "ROCCA",
#             "itemCode": "456",
#             "items": []
#         },
#         {
#             "pattern": "Bread_Croutons_SF",
#             "itemCode": "892",
#             "items": [
#                 {
#                     "itemCode": "820",
#                     "compulsory": false,
#                     "standardQuantity": 12.5,
#                     "items": [
#                         {
#                             "itemCode": "10822",
#                             "compulsory": false,
#                             "standardQuantity": 20.469,
#                             "items": [
#                                 {
#                                     "itemCode": "10161",
#                                     "compulsory": false,
#                                     "standardQuantity": 23.751,
#                                     "items": [
#                                         {
#                                             "itemCode": "5",
#                                             "compulsory": false,
#                                             "standardQuantity": 0.21
#                                         },
#                                         {
#                                             "itemCode": "15",
#                                             "compulsory": false,
#                                             "standardQuantity": 1.118
#                                         },
#                                         {
#                                             "itemCode": "18",
#                                             "compulsory": false,
#                                             "standardQuantity": 0.838
#                                         },
#                                         {
#                                             "itemCode": "92",
#                                             "compulsory": false,
#                                             "standardQuantity": 3.493
#                                         },
#                                         {
#                                             "itemCode": "117",
#                                             "compulsory": false,
#                                             "standardQuantity": 0.21
#                                         },
#                                         {
#                                             "itemCode": "159",
#                                             "compulsory": false,
#                                             "standardQuantity": 0.21
#                                         },
#                                         {
#                                             "itemCode": "258",
#                                             "compulsory": false,
#                                             "standardQuantity": 12.574
#                                         },
#                                         {
#                                             "itemCode": "2745",
#                                             "compulsory": false,
#                                             "standardQuantity": 1.397
#                                         },
#                                         {
#                                             "itemCode": "7991",
#                                             "compulsory": false,
#                                             "standardQuantity": 4.89
#                                         }
#                                     ]
#                                 }
#                             ]
#                         }
#                     ]
#                 }
#             ]
#         },
#         {
#             "pattern": "Berlin_dressing_SF",
#             "itemCode": "965",
#             "items": [
#                 {
#                     "itemCode": "18",
#                     "compulsory": false,
#                     "standardQuantity": 6.713
#                 },
#                 {
#                     "itemCode": "103",
#                     "compulsory": false,
#                     "standardQuantity": 1.333
#                 },
#                 {
#                     "itemCode": "117",
#                     "compulsory": false,
#                     "standardQuantity": 1.333
#                 },
#                 {
#                     "itemCode": "296",
#                     "compulsory": false,
#                     "standardQuantity": 8.0,
#                     "items": [
#                         {
#                             "itemCode": "444",
#                             "compulsory": false,
#                             "standardQuantity": 8.0
#                         }
#                     ]
#                 },
#                 {
#                     "itemCode": "7593",
#                     "compulsory": false,
#                     "standardQuantity": 2.666
#                 }
#             ]
#         },
#         {
#             "pattern": "Boiled_Beetroot_SF",
#             "itemCode": "4291",
#             "items": [
#                 {
#                     "itemCode": "117",
#                     "compulsory": false,
#                     "standardQuantity": 0.956
#                 },
#                 {
#                     "itemCode": "428",
#                     "compulsory": false,
#                     "standardQuantity": 68.274
#                 },
#                 {
#                     "itemCode": "7991",
#                     "compulsory": false,
#                     "standardQuantity": 143.333
#                 }
#             ]
#         },
#         {
#             "pattern": "CHEESE_PARMESAN_LOW_FAT",
#             "itemCode": "90",
#             "items": []
#         },
#         {
#             "pattern": "Caesar_Dressing_SF",
#             "itemCode": "804",
#             "items": [
#                 {
#                     "itemCode": "7",
#                     "compulsory": false,
#                     "standardQuantity": 1.0
#                 },
#                 {
#                     "itemCode": "17",
#                     "compulsory": false,
#                     "standardQuantity": 2.5
#                 },
#                 {
#                     "itemCode": "18",
#                     "compulsory": false,
#                     "standardQuantity": 2.518
#                 },
#                 {
#                     "itemCode": "77",
#                     "compulsory": false,
#                     "standardQuantity": 5.0
#                 },
#                 {
#                     "itemCode": "96",
#                     "compulsory": false,
#                     "standardQuantity": 7.515
#                 },
#                 {
#                     "itemCode": "103",
#                     "compulsory": false,
#                     "standardQuantity": 0.25
#                 },
#                 {
#                     "itemCode": "117",
#                     "compulsory": false,
#                     "standardQuantity": 1.0
#                 },
#                 {
#                     "itemCode": "8077",
#                     "compulsory": false,
#                     "standardQuantity": 2.0
#                 }
#             ]
#         },
#         {
#             "pattern": "Bread_Croutons_SF",
#             "itemCode": "892",
#             "items": [
#                 {
#                     "itemCode": "820",
#                     "compulsory": false,
#                     "standardQuantity": 12.5,
#                     "items": [
#                         {
#                             "itemCode": "10822",
#                             "compulsory": false,
#                             "standardQuantity": 20.469,
#                             "items": [
#                                 {
#                                     "itemCode": "10161",
#                                     "compulsory": false,
#                                     "standardQuantity": 23.751,
#                                     "items": [
#                                         {
#                                             "itemCode": "5",
#                                             "compulsory": false,
#                                             "standardQuantity": 0.21
#                                         },
#                                         {
#                                             "itemCode": "15",
#                                             "compulsory": false,
#                                             "standardQuantity": 1.118
#                                         },
#                                         {
#                                             "itemCode": "18",
#                                             "compulsory": false,
#                                             "standardQuantity": 0.838
#                                         },
#                                         {
#                                             "itemCode": "92",
#                                             "compulsory": false,
#                                             "standardQuantity": 3.493
#                                         },
#                                         {
#                                             "itemCode": "117",
#                                             "compulsory": false,
#                                             "standardQuantity": 0.21
#                                         },
#                                         {
#                                             "itemCode": "159",
#                                             "compulsory": false,
#                                             "standardQuantity": 0.21
#                                         },
#                                         {
#                                             "itemCode": "258",
#                                             "compulsory": false,
#                                             "standardQuantity": 12.574
#                                         },
#                                         {
#                                             "itemCode": "2745",
#                                             "compulsory": false,
#                                             "standardQuantity": 1.397
#                                         },
#                                         {
#                                             "itemCode": "7991",
#                                             "compulsory": false,
#                                             "standardQuantity": 4.89
#                                         }
#                                     ]
#                                 }
#                             ]
#                         }
#                     ]
#                 }
#             ]
#         },
#         {
#             "pattern": "LETTUCE_ROMANIA_",
#             "itemCode": "3297",
#             "items": []
#         },
#         {
#             "pattern": "WALNUT",
#             "itemCode": "355",
#             "items": []
#         },
#         {
#             "pattern": "PARSLEY",
#             "itemCode": "438",
#             "items": []
#         },
#         {
#             "pattern": "LETTUCE_ARABIC",
#             "itemCode": "450",
#             "items": []
#         },
#         {
#             "pattern": "LIME_FRESH",
#             "itemCode": "1087",
#             "items": []
#         },
#         {
#             "pattern": "Creamy_Potato_SF",
#             "itemCode": "4336",
#             "items": [
#                 {
#                     "itemCode": "14",
#                     "compulsory": false,
#                     "standardQuantity": 5.878
#                 },
#                 {
#                     "itemCode": "17",
#                     "compulsory": false,
#                     "standardQuantity": 2.939
#                 },
#                 {
#                     "itemCode": "25",
#                     "compulsory": false,
#                     "standardQuantity": 2.519
#                 },
#                 {
#                     "itemCode": "53",
#                     "compulsory": false,
#                     "standardQuantity": 12.596
#                 },
#                 {
#                     "itemCode": "77",
#                     "compulsory": false,
#                     "standardQuantity": 12.604
#                 },
#                 {
#                     "itemCode": "103",
#                     "compulsory": false,
#                     "standardQuantity": 0.084
#                 },
#                 {
#                     "itemCode": "110",
#                     "compulsory": false,
#                     "standardQuantity": 0.419
#                 },
#                 {
#                     "itemCode": "117",
#                     "compulsory": false,
#                     "standardQuantity": 1.259
#                 },
#                 {
#                     "itemCode": "437",
#                     "compulsory": false,
#                     "standardQuantity": 0.42
#                 },
#                 {
#                     "itemCode": "461",
#                     "compulsory": false,
#                     "standardQuantity": 8.397
#                 },
#                 {
#                     "itemCode": "895",
#                     "compulsory": false,
#                     "standardQuantity": 2.519,
#                     "items": [
#                         {
#                             "itemCode": "444",
#                             "compulsory": false,
#                             "standardQuantity": 2.519
#                         }
#                     ]
#                 },
#                 {
#                     "itemCode": "3101",
#                     "compulsory": false,
#                     "standardQuantity": 2.519
#                 },
#                 {
#                     "itemCode": "4237",
#                     "compulsory": false,
#                     "standardQuantity": 58.779,
#                     "items": [
#                         {
#                             "itemCode": "7991",
#                             "compulsory": false,
#                             "standardQuantity": 207.454
#                         }
#                     ]
#                 }
#             ]
#         }
#     ]
# }
